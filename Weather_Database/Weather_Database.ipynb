# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# create a set of random latitude and longitute combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Import citipy 
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 733

# %%
# Import the requests library
import requests

# Import the API key
import sys
sys.path.append("..")
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# import the time library and the datetime module form the datetime library
import time 
from datetime import datetime

# %%
# create an empty list to hold the weather data
city_data = []

# print the beginning of the logging
print("Beginning Data Retrieval       ")
print("-------------------------------")

# create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | imbituba
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | salalah
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | los llanos de aridane
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | faanui
# Processing Record 17 of Set 1 | ulaangom
# Processing Record 18 of Set 1 | cidreira
# Processing Record 19 of Set 1 | porto novo
# Processing Record 20 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 1 | jabiru
# City not found. Skipping...
# Processing Record 22 of Set 1 | vilyuysk
# Processing Record 23 of Set 1 | kintampo
# Processing Record 24 of Set 1 | lasa
# Processing Record 25 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | mahebourg
# Processing Record 28 of Set 1 | khatanga
# Processing Record 29 of Set 1 | kurumkan
# Processing Record 30 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | ilulissat
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | san isidro
# Processing Record 35 of Set 1 | sambava
# Processing Record 36 of Set 1 | creel
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | sterling
# Processing Record 39 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 1 | sao filipe
# Processing Record 41 of Set 1 | tarko-sale
# Processing Record 42 of Set 1 | codrington
# Processing Record 43 of Set 1 | belmonte
# Processing Record 44 of Set 1 | victoria
# Processing Record 45 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 1 | tiksi
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | kuah
# Processing Record 49 of Set 1 | harper
# Processing Record 50 of Set 1 | haines junction
# Processing Record 1 of Set 2 | santa cruz
# Processing Record 2 of Set 2 | evensk
# Processing Record 3 of Set 2 | aras
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | sola
# Processing Record 6 of Set 2 | broome
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | hervey bay
# Processing Record 9 of Set 2 | huaicheng
# Processing Record 10 of Set 2 | butaritari
# Processing Record 11 of Set 2 | kingsport
# Processing Record 12 of Set 2 | pisco
# Processing Record 13 of Set 2 | mujiayingzi
# Processing Record 14 of Set 2 | bayangol
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 18 of Set 2 | kez
# Processing Record 19 of Set 2 | bambous virieux
# Processing Record 20 of Set 2 | leningradskiy
# Processing Record 21 of Set 2 | atar
# Processing Record 22 of Set 2 | cervo
# Processing Record 23 of Set 2 | sao goncalo do amarante
# Processing Record 24 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 2 | nikolskoye
# Processing Record 26 of Set 2 | donzdorf
# Processing Record 27 of Set 2 | narsaq
# Processing Record 28 of Set 2 | puro
# Processing Record 29 of Set 2 | rikitea
# Processing Record 30 of Set 2 | pasni
# Processing Record 31 of Set 2 | okhotsk
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | torbay
# Processing Record 34 of Set 2 | cape town
# Processing Record 35 of Set 2 | port elizabeth
# Processing Record 36 of Set 2 | contamana
# Processing Record 37 of Set 2 | sumenep
# Processing Record 38 of Set 2 | piacabucu
# Processing Record 39 of Set 2 | hammerfest
# Processing Record 40 of Set 2 | bada
# Processing Record 41 of Set 2 | avarua
# Processing Record 42 of Set 2 | gorgan
# Processing Record 43 of Set 2 | prince george
# Processing Record 44 of Set 2 | bengkulu
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | norwich
# Processing Record 50 of Set 2 | jacareacanga
# Processing Record 1 of Set 3 | ingham
# Processing Record 2 of Set 3 | laguna
# Processing Record 3 of Set 3 | santa marta
# Processing Record 4 of Set 3 | pemberton
# Processing Record 5 of Set 3 | emerald
# Processing Record 6 of Set 3 | kloulklubed
# Processing Record 7 of Set 3 | chokurdakh
# Processing Record 8 of Set 3 | raymondville
# Processing Record 9 of Set 3 | forte dei marmi
# Processing Record 10 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 3 | carnarvon
# Processing Record 12 of Set 3 | georgetown
# Processing Record 13 of Set 3 | vila velha
# Processing Record 14 of Set 3 | namatanai
# Processing Record 15 of Set 3 | ponta delgada
# Processing Record 16 of Set 3 | mar del plata
# Processing Record 17 of Set 3 | tazovskiy
# Processing Record 18 of Set 3 | huarmey
# Processing Record 19 of Set 3 | smithers
# Processing Record 20 of Set 3 | noyabrsk
# Processing Record 21 of Set 3 | bud
# Processing Record 22 of Set 3 | tanda
# Processing Record 23 of Set 3 | bilibino
# Processing Record 24 of Set 3 | leh
# Processing Record 25 of Set 3 | tabuk
# Processing Record 26 of Set 3 | san cristobal
# Processing Record 27 of Set 3 | razvilnoye
# Processing Record 28 of Set 3 | kodiak
# Processing Record 29 of Set 3 | suntar
# Processing Record 30 of Set 3 | pontianak
# Processing Record 31 of Set 3 | zhengjiatun
# Processing Record 32 of Set 3 | waipawa
# Processing Record 33 of Set 3 | annau
# Processing Record 34 of Set 3 | bambamarca
# Processing Record 35 of Set 3 | tasiilaq
# Processing Record 36 of Set 3 | agnibilekrou
# Processing Record 37 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 38 of Set 3 | shahr-e babak
# Processing Record 39 of Set 3 | talnakh
# Processing Record 40 of Set 3 | mogadouro
# Processing Record 41 of Set 3 | luganville
# Processing Record 42 of Set 3 | bulawayo
# Processing Record 43 of Set 3 | farah
# Processing Record 44 of Set 3 | iqaluit
# Processing Record 45 of Set 3 | airai
# Processing Record 46 of Set 3 | fort-shevchenko
# Processing Record 47 of Set 3 | cabo san lucas
# Processing Record 48 of Set 3 | bredasdorp
# Processing Record 49 of Set 3 | nitra
# Processing Record 50 of Set 3 | caravelas
# Processing Record 1 of Set 4 | tura
# Processing Record 2 of Set 4 | najran
# Processing Record 3 of Set 4 | kavieng
# Processing Record 4 of Set 4 | durango
# Processing Record 5 of Set 4 | marsh harbour
# Processing Record 6 of Set 4 | port moresby
# Processing Record 7 of Set 4 | liwale
# Processing Record 8 of Set 4 | bireun
# Processing Record 9 of Set 4 | maceio
# Processing Record 10 of Set 4 | dikson
# Processing Record 11 of Set 4 | luhyny
# Processing Record 12 of Set 4 | kiunga
# Processing Record 13 of Set 4 | nombre de dios
# Processing Record 14 of Set 4 | clyde river
# Processing Record 15 of Set 4 | saint george
# Processing Record 16 of Set 4 | yatou
# Processing Record 17 of Set 4 | lata
# Processing Record 18 of Set 4 | deputatskiy
# Processing Record 19 of Set 4 | severo-yeniseyskiy
# Processing Record 20 of Set 4 | port-de-bouc
# Processing Record 21 of Set 4 | siedlce
# Processing Record 22 of Set 4 | blyznyuky
# Processing Record 23 of Set 4 | padang
# Processing Record 24 of Set 4 | half moon bay
# Processing Record 25 of Set 4 | ksenyevka
# City not found. Skipping...
# Processing Record 26 of Set 4 | sept-iles
# Processing Record 27 of Set 4 | biak
# Processing Record 28 of Set 4 | souillac
# Processing Record 29 of Set 4 | moissala
# Processing Record 30 of Set 4 | andenes
# Processing Record 31 of Set 4 | guarizama
# Processing Record 32 of Set 4 | longyearbyen
# Processing Record 33 of Set 4 | taksimo
# Processing Record 34 of Set 4 | east london
# Processing Record 35 of Set 4 | vardo
# Processing Record 36 of Set 4 | kutum
# Processing Record 37 of Set 4 | kirkuk
# Processing Record 38 of Set 4 | pevek
# Processing Record 39 of Set 4 | lokachi
# Processing Record 40 of Set 4 | hofn
# Processing Record 41 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 4 | altay
# Processing Record 43 of Set 4 | coihaique
# Processing Record 44 of Set 4 | kapaa
# Processing Record 45 of Set 4 | minsk
# Processing Record 46 of Set 4 | ballina
# Processing Record 47 of Set 4 | makaryev
# Processing Record 48 of Set 4 | port blair
# Processing Record 49 of Set 4 | palmer
# Processing Record 50 of Set 4 | cherskiy
# Processing Record 1 of Set 5 | prieska
# Processing Record 2 of Set 5 | rocha
# Processing Record 3 of Set 5 | adrar
# Processing Record 4 of Set 5 | hamilton
# Processing Record 5 of Set 5 | trincomalee
# Processing Record 6 of Set 5 | san vicente
# Processing Record 7 of Set 5 | lebu
# Processing Record 8 of Set 5 | stupava
# Processing Record 9 of Set 5 | concepcion
# Processing Record 10 of Set 5 | powell river
# Processing Record 11 of Set 5 | tigil
# Processing Record 12 of Set 5 | thompson
# Processing Record 13 of Set 5 | ust-nera
# Processing Record 14 of Set 5 | anadyr
# Processing Record 15 of Set 5 | cayhagan
# Processing Record 16 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 5 | gat
# Processing Record 18 of Set 5 | cayenne
# Processing Record 19 of Set 5 | jalu
# Processing Record 20 of Set 5 | dom pedrito
# Processing Record 21 of Set 5 | upernavik
# Processing Record 22 of Set 5 | wasilla
# Processing Record 23 of Set 5 | skara
# Processing Record 24 of Set 5 | namibe
# Processing Record 25 of Set 5 | road town
# Processing Record 26 of Set 5 | puerto escondido
# Processing Record 27 of Set 5 | labuhan
# Processing Record 28 of Set 5 | saint-philippe
# Processing Record 29 of Set 5 | balkhash
# Processing Record 30 of Set 5 | puerto ayacucho
# Processing Record 31 of Set 5 | port augusta
# Processing Record 32 of Set 5 | nieuw amsterdam
# Processing Record 33 of Set 5 | aklavik
# Processing Record 34 of Set 5 | arawa
# Processing Record 35 of Set 5 | jinchang
# Processing Record 36 of Set 5 | ambunti
# Processing Record 37 of Set 5 | provideniya
# Processing Record 38 of Set 5 | orel-izumrud
# Processing Record 39 of Set 5 | melendugno
# Processing Record 40 of Set 5 | roald
# Processing Record 41 of Set 5 | puerto ayora
# Processing Record 42 of Set 5 | asau
# Processing Record 43 of Set 5 | kruisfontein
# Processing Record 44 of Set 5 | grand gaube
# Processing Record 45 of Set 5 | coihueco
# Processing Record 46 of Set 5 | castro
# Processing Record 47 of Set 5 | sinnamary
# Processing Record 48 of Set 5 | praia da vitoria
# Processing Record 49 of Set 5 | baiao
# Processing Record 50 of Set 5 | norman wells
# Processing Record 1 of Set 6 | honningsvag
# Processing Record 2 of Set 6 | danjiangkou
# Processing Record 3 of Set 6 | brae
# Processing Record 4 of Set 6 | bolitoc
# Processing Record 5 of Set 6 | la palma
# Processing Record 6 of Set 6 | nanortalik
# Processing Record 7 of Set 6 | acapulco
# Processing Record 8 of Set 6 | tra vinh
# Processing Record 9 of Set 6 | ilebo
# Processing Record 10 of Set 6 | arraial do cabo
# Processing Record 11 of Set 6 | churapcha
# Processing Record 12 of Set 6 | lazarev
# Processing Record 13 of Set 6 | umm lajj
# Processing Record 14 of Set 6 | lazaro cardenas
# Processing Record 15 of Set 6 | stornoway
# Processing Record 16 of Set 6 | emba
# Processing Record 17 of Set 6 | santiago del estero
# Processing Record 18 of Set 6 | wattegama
# Processing Record 19 of Set 6 | klaksvik
# Processing Record 20 of Set 6 | saint-augustin
# Processing Record 21 of Set 6 | touros
# Processing Record 22 of Set 6 | coruripe
# Processing Record 23 of Set 6 | kavaratti
# Processing Record 24 of Set 6 | chuy
# Processing Record 25 of Set 6 | kaitangata
# Processing Record 26 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 6 | chojnice
# Processing Record 28 of Set 6 | margate
# Processing Record 29 of Set 6 | ordynskoye
# Processing Record 30 of Set 6 | fortuna
# Processing Record 31 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 32 of Set 6 | arenapolis
# Processing Record 33 of Set 6 | geraldton
# Processing Record 34 of Set 6 | awjilah
# Processing Record 35 of Set 6 | kochubey
# Processing Record 36 of Set 6 | kangema
# Processing Record 37 of Set 6 | basco
# Processing Record 38 of Set 6 | kandrian
# Processing Record 39 of Set 6 | tabou
# Processing Record 40 of Set 6 | aloleng
# Processing Record 41 of Set 6 | kabare
# Processing Record 42 of Set 6 | collie
# Processing Record 43 of Set 6 | presidencia roque saenz pena
# Processing Record 44 of Set 6 | koygorodok
# Processing Record 45 of Set 6 | bandundu
# Processing Record 46 of Set 6 | severo-kurilsk
# Processing Record 47 of Set 6 | galchino
# City not found. Skipping...
# Processing Record 48 of Set 6 | burnie
# Processing Record 49 of Set 6 | kostarazion
# City not found. Skipping...
# Processing Record 50 of Set 6 | batagay-alyta
# Processing Record 1 of Set 7 | lagunas
# Processing Record 2 of Set 7 | sembe
# Processing Record 3 of Set 7 | tommot
# Processing Record 4 of Set 7 | mount gambier
# Processing Record 5 of Set 7 | honiara
# Processing Record 6 of Set 7 | quang ngai
# Processing Record 7 of Set 7 | galesong
# Processing Record 8 of Set 7 | komsomolskiy
# Processing Record 9 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 7 | linhares
# Processing Record 11 of Set 7 | lagoa
# Processing Record 12 of Set 7 | weligama
# Processing Record 13 of Set 7 | gazanjyk
# Processing Record 14 of Set 7 | ketchikan
# Processing Record 15 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 7 | henties bay
# Processing Record 17 of Set 7 | baykit
# Processing Record 18 of Set 7 | canmore
# Processing Record 19 of Set 7 | san patricio
# Processing Record 20 of Set 7 | zeya
# Processing Record 21 of Set 7 | belaya gora
# Processing Record 22 of Set 7 | laurentides
# Processing Record 23 of Set 7 | methven
# Processing Record 24 of Set 7 | olinda
# Processing Record 25 of Set 7 | mihijam
# Processing Record 26 of Set 7 | pljevlja
# Processing Record 27 of Set 7 | obo
# Processing Record 28 of Set 7 | tuatapere
# Processing Record 29 of Set 7 | luderitz
# Processing Record 30 of Set 7 | hay river
# Processing Record 31 of Set 7 | yarmouth
# Processing Record 32 of Set 7 | ponta do sol
# Processing Record 33 of Set 7 | almaznyy
# Processing Record 34 of Set 7 | lethem
# Processing Record 35 of Set 7 | quchan
# Processing Record 36 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 7 | maniitsoq
# Processing Record 38 of Set 7 | kununurra
# Processing Record 39 of Set 7 | saint simons
# Processing Record 40 of Set 7 | dawson creek
# Processing Record 41 of Set 7 | baculin
# Processing Record 42 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 7 | erenhot
# Processing Record 44 of Set 7 | nosy varika
# Processing Record 45 of Set 7 | bengbu
# Processing Record 46 of Set 7 | campbellton
# Processing Record 47 of Set 7 | kieta
# Processing Record 48 of Set 7 | te anau
# Processing Record 49 of Set 7 | sibolga
# Processing Record 50 of Set 7 | manicore
# Processing Record 1 of Set 8 | el alto
# Processing Record 2 of Set 8 | fuxin
# Processing Record 3 of Set 8 | guerrero negro
# Processing Record 4 of Set 8 | southampton
# Processing Record 5 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 8 | bukama
# Processing Record 7 of Set 8 | azare
# Processing Record 8 of Set 8 | pecos
# Processing Record 9 of Set 8 | port hawkesbury
# Processing Record 10 of Set 8 | alofi
# Processing Record 11 of Set 8 | priladozhskiy
# Processing Record 12 of Set 8 | voh
# Processing Record 13 of Set 8 | havelock
# Processing Record 14 of Set 8 | rabaul
# Processing Record 15 of Set 8 | yinchuan
# Processing Record 16 of Set 8 | anori
# Processing Record 17 of Set 8 | denpasar
# Processing Record 18 of Set 8 | puerto rondon
# Processing Record 19 of Set 8 | khani
# Processing Record 20 of Set 8 | dzilam gonzalez
# Processing Record 21 of Set 8 | quimper
# Processing Record 22 of Set 8 | tromso
# Processing Record 23 of Set 8 | rio grande
# Processing Record 24 of Set 8 | berlevag
# Processing Record 25 of Set 8 | pangnirtung
# Processing Record 26 of Set 8 | meshcherino
# Processing Record 27 of Set 8 | meulaboh
# Processing Record 28 of Set 8 | saint-pierre
# Processing Record 29 of Set 8 | pekalongan
# Processing Record 30 of Set 8 | mascota
# Processing Record 31 of Set 8 | vila franca do campo
# Processing Record 32 of Set 8 | la tuque
# Processing Record 33 of Set 8 | nchelenge
# Processing Record 34 of Set 8 | aksarka
# Processing Record 35 of Set 8 | alamos
# Processing Record 36 of Set 8 | verkhnyaya sinyachikha
# Processing Record 37 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 38 of Set 8 | lively
# Processing Record 39 of Set 8 | kahului
# Processing Record 40 of Set 8 | areia branca
# Processing Record 41 of Set 8 | zaysan
# Processing Record 42 of Set 8 | kushmurun
# Processing Record 43 of Set 8 | ostrovnoy
# Processing Record 44 of Set 8 | srednekolymsk
# Processing Record 45 of Set 8 | lantana
# Processing Record 46 of Set 8 | strezhevoy
# Processing Record 47 of Set 8 | bonavista
# Processing Record 48 of Set 8 | two rivers
# Processing Record 49 of Set 8 | hasaki
# Processing Record 50 of Set 8 | mayumba
# Processing Record 1 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 9 | pedernales
# Processing Record 3 of Set 9 | yar-sale
# Processing Record 4 of Set 9 | aasiaat
# Processing Record 5 of Set 9 | miramar
# Processing Record 6 of Set 9 | bozhou
# Processing Record 7 of Set 9 | calama
# Processing Record 8 of Set 9 | bahia blanca
# Processing Record 9 of Set 9 | sartell
# Processing Record 10 of Set 9 | nampula
# Processing Record 11 of Set 9 | panama city
# Processing Record 12 of Set 9 | pimentel
# Processing Record 13 of Set 9 | jomalig
# City not found. Skipping...
# Processing Record 14 of Set 9 | port lincoln
# Processing Record 15 of Set 9 | pouembout
# Processing Record 16 of Set 9 | inhambane
# Processing Record 17 of Set 9 | fasa
# Processing Record 18 of Set 9 | camacupa
# Processing Record 19 of Set 9 | olafsvik
# Processing Record 20 of Set 9 | windhoek
# Processing Record 21 of Set 9 | teneguiban
# City not found. Skipping...
# Processing Record 22 of Set 9 | othonoi
# City not found. Skipping...
# Processing Record 23 of Set 9 | tombouctou
# Processing Record 24 of Set 9 | muros
# Processing Record 25 of Set 9 | awbari
# Processing Record 26 of Set 9 | correntina
# Processing Record 27 of Set 9 | lompoc
# Processing Record 28 of Set 9 | am timan
# Processing Record 29 of Set 9 | tacuarembo
# Processing Record 30 of Set 9 | alice springs
# Processing Record 31 of Set 9 | hobyo
# Processing Record 32 of Set 9 | marzuq
# Processing Record 33 of Set 9 | lusambo
# Processing Record 34 of Set 9 | north platte
# Processing Record 35 of Set 9 | ayer itam
# City not found. Skipping...
# Processing Record 36 of Set 9 | dakar
# Processing Record 37 of Set 9 | sitka
# Processing Record 38 of Set 9 | cabedelo
# Processing Record 39 of Set 9 | labrea
# Processing Record 40 of Set 9 | mizpe ramon
# City not found. Skipping...
# Processing Record 41 of Set 9 | aksu
# Processing Record 42 of Set 9 | camacha
# Processing Record 43 of Set 9 | shirokiy
# Processing Record 44 of Set 9 | taltal
# Processing Record 45 of Set 9 | san ignacio
# Processing Record 46 of Set 9 | jiuquan
# Processing Record 47 of Set 9 | urucara
# Processing Record 48 of Set 9 | buchanan
# Processing Record 49 of Set 9 | zambezi
# Processing Record 50 of Set 9 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 1 of Set 10 | kirakira
# Processing Record 2 of Set 10 | thinadhoo
# Processing Record 3 of Set 10 | hargeysa
# Processing Record 4 of Set 10 | qui nhon
# Processing Record 5 of Set 10 | gravdal
# Processing Record 6 of Set 10 | abalak
# Processing Record 7 of Set 10 | kabo
# Processing Record 8 of Set 10 | saldanha
# Processing Record 9 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 10 of Set 10 | banamba
# Processing Record 11 of Set 10 | sisimiut
# Processing Record 12 of Set 10 | necochea
# Processing Record 13 of Set 10 | morshansk
# Processing Record 14 of Set 10 | harigue
# City not found. Skipping...
# Processing Record 15 of Set 10 | brasileia
# Processing Record 16 of Set 10 | muzhi
# Processing Record 17 of Set 10 | prescott
# Processing Record 18 of Set 10 | vostok
# Processing Record 19 of Set 10 | lodja
# Processing Record 20 of Set 10 | husavik
# Processing Record 21 of Set 10 | soe
# Processing Record 22 of Set 10 | owo
# Processing Record 23 of Set 10 | kuytun
# Processing Record 24 of Set 10 | torrington
# Processing Record 25 of Set 10 | lerik
# Processing Record 26 of Set 10 | manokwari
# Processing Record 27 of Set 10 | vetapalem
# Processing Record 28 of Set 10 | khorramshahr
# Processing Record 29 of Set 10 | kalmunai
# Processing Record 30 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 10 | leshukonskoye
# Processing Record 32 of Set 10 | vanimo
# Processing Record 33 of Set 10 | gazojak
# Processing Record 34 of Set 10 | north bend
# Processing Record 35 of Set 10 | hambantota
# Processing Record 36 of Set 10 | long branch
# Processing Record 37 of Set 10 | berzence
# Processing Record 38 of Set 10 | briancon
# Processing Record 39 of Set 10 | pandan
# Processing Record 40 of Set 10 | poum
# Processing Record 41 of Set 10 | barrhead
# Processing Record 42 of Set 10 | xiangfan
# Processing Record 43 of Set 10 | coquimbo
# Processing Record 44 of Set 10 | ovre ardal
# Processing Record 45 of Set 10 | porto santo
# Processing Record 46 of Set 10 | vitim
# Processing Record 47 of Set 10 | nelson bay
# Processing Record 48 of Set 10 | tuskegee
# Processing Record 49 of Set 10 | nayoro
# Processing Record 50 of Set 10 | palafrugell
# Processing Record 1 of Set 11 | kamenka
# Processing Record 2 of Set 11 | isangel
# Processing Record 3 of Set 11 | safford
# Processing Record 4 of Set 11 | balaipungut
# Processing Record 5 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 11 | samarai
# Processing Record 7 of Set 11 | kota bahru
# Processing Record 8 of Set 11 | buta
# Processing Record 9 of Set 11 | belyy yar
# Processing Record 10 of Set 11 | buraydah
# Processing Record 11 of Set 11 | salzkotten
# Processing Record 12 of Set 11 | nome
# Processing Record 13 of Set 11 | dingle
# Processing Record 14 of Set 11 | benguela
# Processing Record 15 of Set 11 | birkeland
# Processing Record 16 of Set 11 | opuwo
# Processing Record 17 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 11 | vila
# Processing Record 19 of Set 11 | nexo
# Processing Record 20 of Set 11 | russell
# Processing Record 21 of Set 11 | campbell river
# Processing Record 22 of Set 11 | moron
# Processing Record 23 of Set 11 | terre-de-bas
# Processing Record 24 of Set 11 | salmas
# Processing Record 25 of Set 11 | zhezkazgan
# Processing Record 26 of Set 11 | tual
# Processing Record 27 of Set 11 | marrakesh
# Processing Record 28 of Set 11 | abha
# Processing Record 29 of Set 11 | codajas
# Processing Record 30 of Set 11 | katastarion
# Processing Record 31 of Set 11 | ceres
# Processing Record 32 of Set 11 | mormugao
# Processing Record 33 of Set 11 | sembakung
# Processing Record 34 of Set 11 | dunedin
# Processing Record 35 of Set 11 | lavrentiya
# Processing Record 36 of Set 11 | pochutla
# Processing Record 37 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 38 of Set 11 | tuy hoa
# Processing Record 39 of Set 11 | darhan
# Processing Record 40 of Set 11 | afanasyevo
# City not found. Skipping...
# Processing Record 41 of Set 11 | gayny
# Processing Record 42 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 11 | rundu
# Processing Record 44 of Set 11 | politika
# Processing Record 45 of Set 11 | osmena
# Processing Record 46 of Set 11 | ulladulla
# Processing Record 47 of Set 11 | wad madani
# Processing Record 48 of Set 11 | ambon
# Processing Record 49 of Set 11 | tonj
# Processing Record 50 of Set 11 | alyangula
# Processing Record 1 of Set 12 | nambucca heads
# Processing Record 2 of Set 12 | bambanglipuro
# Processing Record 3 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 4 of Set 12 | muriwai beach
# Processing Record 5 of Set 12 | maltahohe
# Processing Record 6 of Set 12 | tessalit
# Processing Record 7 of Set 12 | kaeo
# Processing Record 8 of Set 12 | ancud
# Processing Record 9 of Set 12 | brindisi
# Processing Record 10 of Set 12 | havoysund
# Processing Record 11 of Set 12 | luanda
# Processing Record 12 of Set 12 | aranos
# Processing Record 13 of Set 12 | portland
# Processing Record 14 of Set 12 | suoyarvi
# Processing Record 15 of Set 12 | nouadhibou
# Processing Record 16 of Set 12 | chicama
# Processing Record 17 of Set 12 | tautira
# Processing Record 18 of Set 12 | braganca
# Processing Record 19 of Set 12 | bathsheba
# Processing Record 20 of Set 12 | hirara
# Processing Record 21 of Set 12 | ixtapa
# Processing Record 22 of Set 12 | ayoquezco
# City not found. Skipping...
# Processing Record 23 of Set 12 | langres
# Processing Record 24 of Set 12 | matamoros
# Processing Record 25 of Set 12 | voloshka
# Processing Record 26 of Set 12 | yerbogachen
# Processing Record 27 of Set 12 | manthani
# Processing Record 28 of Set 12 | matagami
# Processing Record 29 of Set 12 | poso
# Processing Record 30 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 12 | tapes
# Processing Record 32 of Set 12 | lorengau
# Processing Record 33 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 34 of Set 12 | verkhnetulomskiy
# Processing Record 35 of Set 12 | muika
# City not found. Skipping...
# Processing Record 36 of Set 12 | fairbanks
# Processing Record 37 of Set 12 | zhongshu
# Processing Record 38 of Set 12 | scharnstein
# Processing Record 39 of Set 12 | mubi
# Processing Record 40 of Set 12 | la ronge
# Processing Record 41 of Set 12 | sur
# Processing Record 42 of Set 12 | tarnogskiy gorodok
# Processing Record 43 of Set 12 | constitucion
# Processing Record 44 of Set 12 | rawson
# Processing Record 45 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 46 of Set 12 | rantepao
# Processing Record 47 of Set 12 | fayaoue
# Processing Record 48 of Set 12 | salinopolis
# Processing Record 49 of Set 12 | houma
# Processing Record 50 of Set 12 | ternate
# Processing Record 1 of Set 13 | jadu
# Processing Record 2 of Set 13 | coolum beach
# Processing Record 3 of Set 13 | gdov
# Processing Record 4 of Set 13 | juneau
# Processing Record 5 of Set 13 | coari
# Processing Record 6 of Set 13 | bubaque
# Processing Record 7 of Set 13 | donegal
# Processing Record 8 of Set 13 | kadhan
# Processing Record 9 of Set 13 | zhigansk
# Processing Record 10 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 11 of Set 13 | esperance
# Processing Record 12 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 13 of Set 13 | charters towers
# Processing Record 14 of Set 13 | stantsionno-oyashinskiy
# Processing Record 15 of Set 13 | fez
# Processing Record 16 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 17 of Set 13 | mutoko
# Processing Record 18 of Set 13 | bocholt
# Processing Record 19 of Set 13 | fagersta
# Processing Record 20 of Set 13 | cornelio procopio
# Processing Record 21 of Set 13 | dalbandin
# Processing Record 22 of Set 13 | bose
# Processing Record 23 of Set 13 | kupang
# Processing Record 24 of Set 13 | san francisco del mar
# Processing Record 25 of Set 13 | oktyabrskoye
# Processing Record 26 of Set 13 | mount isa
# Processing Record 27 of Set 13 | maxixe
# Processing Record 28 of Set 13 | jardim
# Processing Record 29 of Set 13 | jacksonville
# Processing Record 30 of Set 13 | kaoma
# Processing Record 31 of Set 13 | miri
# Processing Record 32 of Set 13 | enid
# Processing Record 33 of Set 13 | aswan
# Processing Record 34 of Set 13 | kenora
# Processing Record 35 of Set 13 | peniche
# Processing Record 36 of Set 13 | udachnyy
# Processing Record 37 of Set 13 | culiacan
# Processing Record 38 of Set 13 | okato
# Processing Record 39 of Set 13 | iracoubo
# Processing Record 40 of Set 13 | vestmannaeyjar
# Processing Record 41 of Set 13 | taoudenni
# Processing Record 42 of Set 13 | chekhov
# Processing Record 43 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 45 of Set 13 | yudong
# Processing Record 46 of Set 13 | kushiro
# Processing Record 47 of Set 13 | banda aceh
# Processing Record 48 of Set 13 | shache
# Processing Record 49 of Set 13 | yucca valley
# Processing Record 50 of Set 13 | enugu
# Processing Record 1 of Set 14 | eyl
# Processing Record 2 of Set 14 | muroto
# Processing Record 3 of Set 14 | grimari
# City not found. Skipping...
# Processing Record 4 of Set 14 | itoman
# Processing Record 5 of Set 14 | mogadishu
# Processing Record 6 of Set 14 | marawi
# Processing Record 7 of Set 14 | velizh
# Processing Record 8 of Set 14 | zdvinsk
# Processing Record 9 of Set 14 | linxia
# Processing Record 10 of Set 14 | the valley
# Processing Record 11 of Set 14 | ilula
# Processing Record 12 of Set 14 | morondava
# Processing Record 13 of Set 14 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 14 of Set 14 | hami
# Processing Record 15 of Set 14 | aykhal
# Processing Record 16 of Set 14 | naze
# Processing Record 17 of Set 14 | miyako
# Processing Record 18 of Set 14 | bang saphan
# Processing Record 19 of Set 14 | mangalia
# Processing Record 20 of Set 14 | beringovskiy
# Processing Record 21 of Set 14 | pacific grove
# Processing Record 22 of Set 14 | magadan
# Processing Record 23 of Set 14 | thunder bay
# Processing Record 24 of Set 14 | toora-khem
# Processing Record 25 of Set 14 | bobcaygeon
# Processing Record 26 of Set 14 | scarborough
# Processing Record 27 of Set 14 | sarangani
# Processing Record 28 of Set 14 | terrace
# Processing Record 29 of Set 14 | pachino
# Processing Record 30 of Set 14 | lubumbashi
# Processing Record 31 of Set 14 | rosendal
# Processing Record 32 of Set 14 | barcelona
# Processing Record 33 of Set 14 | quatre cocos
# Processing Record 34 of Set 14 | vieux-habitants
# Processing Record 35 of Set 14 | tortoli
# Processing Record 36 of Set 14 | tanggu
# Processing Record 37 of Set 14 | bonfim
# Processing Record 38 of Set 14 | wenling
# Processing Record 39 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 40 of Set 14 | along
# Processing Record 41 of Set 14 | qasigiannguit
# Processing Record 42 of Set 14 | travagliato
# Processing Record 43 of Set 14 | svetlogorsk
# Processing Record 44 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 45 of Set 14 | bandarbeyla
# Processing Record 46 of Set 14 | katsuura
# Processing Record 47 of Set 14 | estelle
# Processing Record 48 of Set 14 | albert
# Processing Record 49 of Set 14 | vung tau
# Processing Record 50 of Set 14 | pemba
# Processing Record 1 of Set 15 | mehamn
# Processing Record 2 of Set 15 | launceston
# Processing Record 3 of Set 15 | eenhana
# Processing Record 4 of Set 15 | malakal
# Processing Record 5 of Set 15 | mananara
# Processing Record 6 of Set 15 | roebourne
# Processing Record 7 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 8 of Set 15 | itatiaia
# Processing Record 9 of Set 15 | vulcan
# Processing Record 10 of Set 15 | kendari
# Processing Record 11 of Set 15 | bereda
# Processing Record 12 of Set 15 | axim
# Processing Record 13 of Set 15 | davila
# Processing Record 14 of Set 15 | san quintin
# Processing Record 15 of Set 15 | noumea
# Processing Record 16 of Set 15 | khash
# Processing Record 17 of Set 15 | nicolas bravo
# Processing Record 18 of Set 15 | salvador
# Processing Record 19 of Set 15 | palmerston
# Processing Record 20 of Set 15 | villablino
# Processing Record 21 of Set 15 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 15 | labytnangi
# Processing Record 23 of Set 15 | auki
# Processing Record 24 of Set 15 | huntingdon
# Processing Record 25 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 26 of Set 15 | nichinan
# Processing Record 27 of Set 15 | sanmenxia
# Processing Record 28 of Set 15 | cobija
# Processing Record 29 of Set 15 | knyaze-volkonskoye
# Processing Record 30 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 31 of Set 15 | cambridge
# Processing Record 32 of Set 15 | maldonado
# Processing Record 33 of Set 15 | dabhol
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                Mataura -46.1927  168.8643     66.47        24          75
# 1              Jamestown  42.0970  -79.2353     13.32        85         100
# 2                 Albany  42.6001  -73.9662     20.91        70         100
# 3                  Bluff -46.6000  168.3333     66.79        63          91
# 4                 Bethel  41.3712  -73.4140     30.29        86         100
# 5               Hermanus -34.4187   19.2345     59.81        81          35
# 6               Imbituba -28.2400  -48.6703     70.83        79          95
# 7                Salalah  17.0151   54.0924     69.89        49           0
# 8            Port Alfred -33.5906   26.8910     66.45        81          91
# 9  Los Llanos De Aridane  28.6585  -17.9182     55.15        67           0
#
#    Wind Speed Country Current Description                 Date
# 0        7.23      NZ       broken clouds  2022-01-29 03:43:21
# 1       10.36      US     overcast clouds  2022-01-29 03:39:09
# 2        3.00      US     overcast clouds  2022-01-29 03:43:22
# 3        8.05      NZ     overcast clouds  2022-01-29 03:43:22
# 4        1.99      US     overcast clouds  2022-01-29 03:43:22
# 5       11.90      ZA    scattered clouds  2022-01-29 03:43:23
# 6        5.48      BR     overcast clouds  2022-01-29 03:43:23
# 7        5.75      OM           clear sky  2022-01-29 03:43:23
# 8        5.61      ZA          light rain  2022-01-29 03:40:34
# 9        9.22      ES           clear sky  2022-01-29 03:40:03

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                Mataura      NZ -46.1927  168.8643     66.47        24
# 1              Jamestown      US  42.0970  -79.2353     13.32        85
# 2                 Albany      US  42.6001  -73.9662     20.91        70
# 3                  Bluff      NZ -46.6000  168.3333     66.79        63
# 4                 Bethel      US  41.3712  -73.4140     30.29        86
# 5               Hermanus      ZA -34.4187   19.2345     59.81        81
# 6               Imbituba      BR -28.2400  -48.6703     70.83        79
# 7                Salalah      OM  17.0151   54.0924     69.89        49
# 8            Port Alfred      ZA -33.5906   26.8910     66.45        81
# 9  Los Llanos De Aridane      ES  28.6585  -17.9182     55.15        67
#
#    Cloudiness  Wind Speed Current Description
# 0          75        7.23       broken clouds
# 1         100       10.36     overcast clouds
# 2         100        3.00     overcast clouds
# 3          91        8.05     overcast clouds
# 4         100        1.99     overcast clouds
# 5          35       11.90    scattered clouds
# 6          95        5.48     overcast clouds
# 7           0        5.75           clear sky
# 8          91        5.61          light rain
# 9           0        9.22           clear sky

# %%
# create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

# export the City_data into a CSV
city_data_df.to_csv(output_data_file, index_label = "City_ID")
